# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from pandas import DataFrame 
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'C:\Users\S Moyo\Downloads\iris-species\Iris.csv')

# %%
print(data.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
print(data.tail(10))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
darr = np.array(df)

# %%
darr
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
darr.shape
# Out:
# (150, 6)

# %%
sepal_length = df["SepalLengthCm"]

# %%
sepal_width = df["SepalWidthCm"]

# %%
petal_length = df["PetalLengthCm"]

# %%
petal_width = df["PetalWidthCm"]

# %%
species = df["Species"]

# %%
plt.hist(sepal_length)
plt.hist(sepal_width)
plt.hist(petal_length)
plt.hist(petal_width)
# Out:
# (array([ 41.,   8.,   1.,   7.,   8.,  33.,   6.,  23.,   9.,  14.]),
#  array([ 0.1 ,  0.34,  0.58,  0.82,  1.06,  1.3 ,  1.54,  1.78,  2.02,
#          2.26,  2.5 ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(sepal_length,sepal_width)

# %%
plt.scatter(sepal_length,petal_length)

# %%
plt.scatter(petal_length,petal_width)

# %%
plt.bar(sepal_length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-000da1f7db17> in <module>()
# ----> 1 plt.bar(sepal_length)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
plt.bar(sepal_width,petal_width,label='width')
# Out:
# <Container object of 10 artists>

# %%
sepal_length
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9], dtype=object)

# %%
x = df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y = pd.get_dummies(df["Species"])
y
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# 5              1                0               0
# 6              1                0               0
# 7              1                0               0
# 8              1                0               0
# 9              1                0               0
# 10             1                0               0
# 11             1                0               0
# 12             1                0               0
# 13             1                0               0
# 14             1                0               0
# 15             1                0               0
# 16             1                0               0
# 17             1                0               0
# ...

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
lr = LinearRegression()

# %%
reg = lr.fit(xTrain, yTrain)

# %%
species_pred = lr.predict(xTest)

# %%
species_pred
# Out:
# array([[ -1.09931141e-01,   1.52823193e-01,   9.57107948e-01],
#        [  1.22817768e-01,   7.89483729e-01,   8.76985034e-02],
#        [  1.17432132e+00,  -2.02700409e-01,   2.83790867e-02],
#        [ -1.98203386e-01,   5.82675403e-01,   6.15527983e-01],
#        [  9.26068525e-01,   1.85671219e-01,  -1.11739745e-01],
#        [ -1.79778930e-01,   9.81890457e-02,   1.08158988e+00],
#        [  9.92874595e-01,   4.10924938e-02,  -3.39670890e-02],
#        [  1.91813991e-01,   2.96815717e-01,   5.11370292e-01],
#        [  1.19126765e-01,   4.78745329e-01,   4.02127906e-01],
#        [  2.46811068e-01,   3.93488200e-01,   3.59700732e-01],
#        [ -2.00748930e-01,   8.52399593e-01,   3.48349338e-01],
#        [  2.29848750e-01,   2.38762845e-01,   5.31388405e-01],
#        [  7.56218165e-02,   6.36046064e-01,   2.88332120e-01],
#        [  1.31819189e-01,   4.06492739e-01,   4.61688071e-01],
#        [  8.79310617e-02,   4.93662438e-01,   4.18406500e-01],
# ...

# %%
print('Coefficients: \n', lr.coef_)
# Out:
# Coefficients:
#  [[ 0.11038558  0.20997972 -0.25076231 -0.04344363]
#  [-0.11443802 -0.37994731  0.27194774 -0.52194448]
#  [ 0.00405244  0.16996759 -0.02118543  0.56538811]]

# %%
lr.coef_
# Out:
# array([[ 0.11038558,  0.20997972, -0.25076231, -0.04344363],
#        [-0.11443802, -0.37994731,  0.27194774, -0.52194448],
#        [ 0.00405244,  0.16996759, -0.02118543,  0.56538811]])

# %%
reg.score(x,y)
# Out:
# 0.59035617200142676

# %%
reg.coef_
# Out:
# array([[ 0.11038558,  0.20997972, -0.25076231, -0.04344363],
#        [-0.11443802, -0.37994731,  0.27194774, -0.52194448],
#        [ 0.00405244,  0.16996759, -0.02118543,  0.56538811]])

# %%
reg.intercept_
# Out:
# array([ 0.04504176,  1.74614945, -0.79119121])

# %%
from sklearn.metrics import confusion_matrix

# %%
#confusion_matrix = confusion_matrix(yTest, yTrain)
#print(confusion_matrix)
yTest.shape
# Out:
# (30, 3)

# %%
yTrain.shape
# Out:
# (120, 3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()
X, y = df(return_X_y=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-2d68494290a9> in <module>()
#       1 lg = LogisticRegression()
# ----> 2 X, y = df(return_X_y=True)
#
# TypeError: 'DataFrame' object is not callable

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs',
                        multi_class='multinomial').fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-505a7bd68cef> in <module>()
# ----> 1 reg2 = lg.fit(xTrain, yTrain)
#
# C:\Users\S Moyo\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# C:\Users\S Moyo\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     524                         dtype=None)
#     525     else:
# --> 526         y = column_or_1d(y, warn=True)
# ...
